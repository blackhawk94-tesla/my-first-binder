# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the csv files which are exported from https://www.gunviolencearchive.org/reports
mass_shootings = pd.read_csv("Gun_violence_mass_shootings.csv")
accidental_deaths = pd.read_csv("Gun_violence_accidental_deaths.csv")
officer_involved_shootings = pd.read_csv("Gun_violence_officers_involved.csv")

# %%
#convert into dataframes and cheack contents 
df_ms = pd.DataFrame(data = mass_shootings)
df_ms.head()
# Out:
#    Incident ID     Incident Date           State City Or County  \
# 0      2516494  February 1, 2023      California    Los Angeles
# 1      2516309  February 1, 2023           Texas     Texas City
# 2      2514902  January 31, 2023  North Carolina         Durham
# 3      2514220  January 30, 2023           Texas         Dallas
# 4      2514564  January 30, 2023         Florida       Lakeland
#
#                         Address  # Killed  # Injured  Operations
# 0   E 108th St and Stanford Ave         0          5         NaN
# 1      8601 Emmett F Lowry Expy         0          4         NaN
# 2      4100 block of Sudbury Rd         2          2         NaN
# 3  5800 block of Bonnie View Rd         1          3         NaN
# 4                923 N Iowa Ave         0         11         NaN

# %%
df_ad = pd.DataFrame(data = accidental_deaths)
df_ad.head()
# Out:
#    Incident ID     Incident Date                 State City Or County  \
# 0      2513961  January 29, 2023             Louisiana    New Orleans
# 1      2514112  January 29, 2023  District of Columbia     Washington
# 2      2514229  January 29, 2023          Pennsylvania    Upper Darby
# 3      2511568  January 22, 2023               Alabama         Mobile
# 4      2508945  January 22, 2023                 Texas     Fort Worth
#
#                          Address  # Killed  # Injured  Operations
# 0      8000 block of Curran Blvd         1          0         NaN
# 1  800 block of Chesapeake St SE         1          0         NaN
# 2               2407 Marshall Rd         1          0         NaN
# 3                            NaN         1          0         NaN
# 4        3700 block of Neches St         1          0         NaN

# %%
df_o = pd.DataFrame(data = officer_involved_shootings)
df_o.head()
# Out:
#    Incident ID    Incident Date         State      City Or County  \
# 0       635289  August 21, 2016     Louisiana         New Orleans
# 1       633604  August 18, 2016    California         Porterville
# 2       631856  August 16, 2016      Illinois  Chicago (Roseland)
# 3       629549  August 14, 2016       Georgia            Marietta
# 4       629915  August 14, 2016  South Dakota            Aberdeen
#
#                          Address  # Killed  # Injured  Operations
# 0      Law St and New Orleans St         1          1         NaN
# 1              Olive St and H St         0          2         NaN
# 2  600 block of East 100th Place         0          1         NaN
# 3           720 Franklin Gateway         0          2         NaN
# 4                324 Marshall St         0          2         NaN

# %%
# dropping address and Operations columns
df_ms.drop(['Operations','Address'],axis = 1,inplace = True)
df_ms.head()
# Out:
#    Incident ID     Incident Date           State City Or County  # Killed  \
# 0      2516494  February 1, 2023      California    Los Angeles         0
# 1      2516309  February 1, 2023           Texas     Texas City         0
# 2      2514902  January 31, 2023  North Carolina         Durham         2
# 3      2514220  January 30, 2023           Texas         Dallas         1
# 4      2514564  January 30, 2023         Florida       Lakeland         0
#
#    # Injured
# 0          5
# 1          4
# 2          2
# 3          3
# 4         11

# %%
df_ad.drop(['Operations','Address'],axis = 1,inplace = True)
df_ad.head()
# Out:
#    Incident ID     Incident Date                 State City Or County  \
# 0      2513961  January 29, 2023             Louisiana    New Orleans
# 1      2514112  January 29, 2023  District of Columbia     Washington
# 2      2514229  January 29, 2023          Pennsylvania    Upper Darby
# 3      2511568  January 22, 2023               Alabama         Mobile
# 4      2508945  January 22, 2023                 Texas     Fort Worth
#
#    # Killed  # Injured
# 0         1          0
# 1         1          0
# 2         1          0
# 3         1          0
# 4         1          0

# %%
df_o.drop(['Operations','Address'],axis = 1,inplace = True)
df_o.head()
# Out:
#    Incident ID    Incident Date         State      City Or County  # Killed  \
# 0       635289  August 21, 2016     Louisiana         New Orleans         1
# 1       633604  August 18, 2016    California         Porterville         0
# 2       631856  August 16, 2016      Illinois  Chicago (Roseland)         0
# 3       629549  August 14, 2016       Georgia            Marietta         0
# 4       629915  August 14, 2016  South Dakota            Aberdeen         0
#
#    # Injured
# 0          1
# 1          2
# 2          1
# 3          2
# 4          2

# %%
df_ms = df_ms.rename(columns={"Incident ID":"Incident_ID", "Incident Date":"Incident_Date", "State":"State", "City Or County":"CityorCounty", "# Killed":"Num_Killed", "# Injured":"Num_Injured"})
df_ms.head()
# Out:
#    Incident_ID     Incident_Date           State CityorCounty  Num_Killed  \
# 0      2516494  February 1, 2023      California  Los Angeles           0
# 1      2516309  February 1, 2023           Texas   Texas City           0
# 2      2514902  January 31, 2023  North Carolina       Durham           2
# 3      2514220  January 30, 2023           Texas       Dallas           1
# 4      2514564  January 30, 2023         Florida     Lakeland           0
#
#    Num_Injured
# 0            5
# 1            4
# 2            2
# 3            3
# 4           11

# %%
df_ad = df_ad.rename(columns={"Incident ID":"Incident_ID", "Incident Date":"Incident_Date", "State":"State", "City Or County":"CityorCounty", "# Killed":"Num_Killed", "# Injured":"Num_Injured"})
df_ad.head()
# Out:
#    Incident_ID     Incident_Date                 State CityorCounty  \
# 0      2513961  January 29, 2023             Louisiana  New Orleans
# 1      2514112  January 29, 2023  District of Columbia   Washington
# 2      2514229  January 29, 2023          Pennsylvania  Upper Darby
# 3      2511568  January 22, 2023               Alabama       Mobile
# 4      2508945  January 22, 2023                 Texas   Fort Worth
#
#    Num_Killed  Num_Injured
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            0

# %%
df_o = df_o.rename(columns={"Incident ID":"Incident_ID", "Incident Date":"Incident_Date", "State":"State", "City Or County":"CityorCounty", "# Killed":"Num_Killed", "# Injured":"Num_Injured"})
df_o.head()
# Out:
#    Incident_ID    Incident_Date         State        CityorCounty  Num_Killed  \
# 0       635289  August 21, 2016     Louisiana         New Orleans           1
# 1       633604  August 18, 2016    California         Porterville           0
# 2       631856  August 16, 2016      Illinois  Chicago (Roseland)           0
# 3       629549  August 14, 2016       Georgia            Marietta           0
# 4       629915  August 14, 2016  South Dakota            Aberdeen           0
#
#    Num_Injured
# 0            1
# 1            2
# 2            1
# 3            2
# 4            2

# %%
from sqlalchemy import create_engine

import pymysql

# %%
tableName = 'mass_shootings'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

 

try:

    frame           = df_ms.to_sql(tableName, dbConnection, if_exists='fail');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table mass_shootings created successfully.

# %%
tableName = 'accidental_deaths_updated'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

 

try:

    frame           = df_ad.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table accidental_deaths_updated created successfully.

# %%
tableName = 'officer_involved_shootings'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

 

try:

    frame           = df_o.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table officer_involved_shootings created successfully.

# %%
#check the proper creation of the table in SQL by querying  
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()
check=pd.read_sql_query('select * from accidental_deaths_updated', con=dbConnection)
dbConnection.close()

# %%
check.head()
# Out:
#    index  Incident_ID     Incident_Date                 State CityorCounty  \
# 0      0      2513961  January 29, 2023             Louisiana  New Orleans
# 1      1      2514112  January 29, 2023  District of Columbia   Washington
# 2      2      2514229  January 29, 2023          Pennsylvania  Upper Darby
# 3      3      2511568  January 22, 2023               Alabama       Mobile
# 4      4      2508945  January 22, 2023                 Texas   Fort Worth
#
#    Num_Killed  Num_Injured
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            0

# %%
#check for duplicates considering Incident_ID as primary key
duplicates = pd.merge(df_ms,df_ad, on="Incident_ID")
len(duplicates['Incident_ID'])
# Out:
# 13

# %%
duplicates = pd.merge(df_ms,df_o, on="Incident_ID")
len(duplicates['Incident_ID'])
# Out:
# 0

# %%
duplicates = pd.merge(df_o,df_ad, on="Incident_ID")
len(duplicates['Incident_ID'])
# Out:
# 0

# %%
count_states = df_ms.drop(["Incident_ID","Num_Injured", "CityorCounty", "Incident_Date"], axis=1)
ms_count=count_states.groupby(['State']).sum().sort_values(['Num_Killed'],ascending = False)
ms_count
# Out:
#                       Num_Killed
# State
# Texas                        203
# California                   190
# Illinois                     161
# North Carolina                85
# Florida                       83
# Georgia                       79
# Michigan                      72
# Ohio                          71
# South Carolina                66
# Pennsylvania                  65
# Colorado                      62
# Louisiana                     60
# Maryland                      60
# New York                      58
# Virginia                      57
# Mississippi                   55
# Indiana                       54
# Missouri                      52
# Alabama                       51
# Tennessee                     48
# Wisconsin                     44
# Arizona                       34
# Oklahoma                      30
# District of Columbia          25
# Minnesota                     22
# New Jersey                    22
# Arkansas                      21
# Washington                    18
# Kentucky                      16
# Nevada                        13
# Utah                          13
# West Virginia                 12
# Oregon                        12
# Iowa                           9
# Nebraska                       9
# Connecticut                    8
# Delaware                       7
# Massachusetts                  6
# Alaska                         6
# Kansas                         5
# Idaho                          5
# South Dakota                   4
# New Mexico                     4
# Maine                          3
# Rhode Island                   0
# New Hampshire                  0

# %%
ms_count.head()
# Out:
#                 Num_Killed
# State
# Texas                  203
# California             190
# Illinois               161
# North Carolina          85
# Florida                 83

# %%
count_states_ad = df_ad.drop(["Incident_ID","Num_Injured", "CityorCounty", "Incident_Date"], axis=1)
ad_count=count_states_ad.groupby(['State']).sum().sort_values(['Num_Killed'],ascending = False)
ad_count.head()
# Out:
#            Num_Killed
# State
# Texas             270
# Florida           133
# Ohio              102
# Georgia            96
# Tennessee          90

# %%
count_states_o = df_o.drop(["Incident_ID","Num_Injured", "CityorCounty", "Incident_Date"], axis=1)
o_count=count_states_o.groupby(['State']).sum().sort_values(['Num_Killed'],ascending = False)
o_count.head()
# Out:
#             Num_Killed
# State
# Louisiana            6
# Texas                5
# Michigan             3
# Alabama              2
# California           2

# %%
#extract year from the date
df_ad['year'] = pd.DatetimeIndex(df_ad['Incident_Date']).year
df_ad.head()
# Out:
#    Incident_ID     Incident_Date                 State CityorCounty  \
# 0      2513961  January 29, 2023             Louisiana  New Orleans
# 1      2514112  January 29, 2023  District of Columbia   Washington
# 2      2514229  January 29, 2023          Pennsylvania  Upper Darby
# 3      2511568  January 22, 2023               Alabama       Mobile
# 4      2508945  January 22, 2023                 Texas   Fort Worth
#
#    Num_Killed  Num_Injured  year
# 0           1            0  2023
# 1           1            0  2023
# 2           1            0  2023
# 3           1            0  2023
# 4           1            0  2023

# %%
df_ad['month'] = pd.DatetimeIndex(df_ad['Incident_Date']).month
df_ad.head()
# Out:
#    Incident_ID     Incident_Date                 State CityorCounty  \
# 0      2513961  January 29, 2023             Louisiana  New Orleans
# 1      2514112  January 29, 2023  District of Columbia   Washington
# 2      2514229  January 29, 2023          Pennsylvania  Upper Darby
# 3      2511568  January 22, 2023               Alabama       Mobile
# 4      2508945  January 22, 2023                 Texas   Fort Worth
#
#    Num_Killed  Num_Injured  year  month
# 0           1            0  2023      1
# 1           1            0  2023      1
# 2           1            0  2023      1
# 3           1            0  2023      1
# 4           1            0  2023      1

# %%
df_test = df_ad.drop(["Incident_ID","Num_Injured", "CityorCounty", "Incident_Date","month","State"],axis = 1)
df_test.head()
# Out:
#    Num_Killed  year
# 0           1  2023
# 1           1  2023
# 2           1  2023
# 3           1  2023
# 4           1  2023

# %%
df_temp=df_test.groupby(['year']).sum().sort_values(['Num_Killed'],ascending = False)
df_temp.head()
# Out:
#       Num_Killed
# year
# 2020         618
# 2021         536
# 2022         458
# 2019         397
# 2023          30

# %%
df_temp['year'] = df_temp.index

# %%
sns.barplot(x = 'year',
            y = 'Num_Killed',
            data = df_temp)
 
# Show the plot
plt.show()

# %%
ms_count['state']=ms_count.index
#ms_count=ms_count.drop(['state'],axis=1)
ms_count.reset_index(drop = True,inplace = True)
ms_count.head()
# Out:
#    Num_Killed           state
# 0         203           Texas
# 1         190      California
# 2         161        Illinois
# 3          85  North Carolina
# 4          83         Florida

# %%
tableName = 'mass_shootings_by_state'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = ms_count.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table mass_shootings_by_state created successfully.

# %%
ad_count['state']=ad_count.index
ad_count.reset_index(drop = True,inplace = True)
ad_count.head()
# Out:
#    Num_Killed      state
# 0         270      Texas
# 1         133    Florida
# 2         102       Ohio
# 3          96    Georgia
# 4          90  Tennessee

# %%
tableName = 'accidental_deaths_by_state'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = ad_count.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table accidental_deaths_by_state created successfully.

# %%
o_count['state']=o_count.index
o_count.reset_index(drop = True,inplace = True)
o_count.head()
# Out:
#    Num_Killed       state
# 0           6   Louisiana
# 1           5       Texas
# 2           3    Michigan
# 3           2     Alabama
# 4           2  California

# %%
tableName = 'officer_involved_deaths_by_state'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = o_count.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table officer_involved_deaths_by_state created successfully.

# %%
df_test_1 = df_ad.drop(["Incident_ID","Num_Injured", "CityorCounty", "Incident_Date","State"],axis = 1)
df_test_1.head()
df_temp_1=df_test_1.groupby(['year','month']).sum().sort_values(['Num_Killed'],ascending = False)
df_temp_1.head()
# Out:
#             Num_Killed
# year month
# 2020 7              75
#      8              67
#      11             57
#      6              57
# 2021 7              55

# %%
df_ad.head()
# Out:
#    Incident_ID     Incident_Date                 State CityorCounty  \
# 0      2513961  January 29, 2023             Louisiana  New Orleans
# 1      2514112  January 29, 2023  District of Columbia   Washington
# 2      2514229  January 29, 2023          Pennsylvania  Upper Darby
# 3      2511568  January 22, 2023               Alabama       Mobile
# 4      2508945  January 22, 2023                 Texas   Fort Worth
#
#    Num_Killed  Num_Injured  year  month
# 0           1            0  2023      1
# 1           1            0  2023      1
# 2           1            0  2023      1
# 3           1            0  2023      1
# 4           1            0  2023      1

# %%
type(df_temp_1.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
#parsing year and month and adding in DataFrames
df_ms['year'] = pd.DatetimeIndex(df_ms['Incident_Date']).year
df_ms['month'] = pd.DatetimeIndex(df_ms['Incident_Date']).month
df_ms.head()
# Out:
#    Incident_ID     Incident_Date           State CityorCounty  Num_Killed  \
# 0      2516494  February 1, 2023      California  Los Angeles           0
# 1      2516309  February 1, 2023           Texas   Texas City           0
# 2      2514902  January 31, 2023  North Carolina       Durham           2
# 3      2514220  January 30, 2023           Texas       Dallas           1
# 4      2514564  January 30, 2023         Florida     Lakeland           0
#
#    Num_Injured  year  month
# 0            5  2023      2
# 1            4  2023      2
# 2            2  2023      1
# 3            3  2023      1
# 4           11  2023      1

# %%
#parsing year and month and adding in DataFrames
df_o['year'] = pd.DatetimeIndex(df_o['Incident_Date']).year
df_o['month'] = pd.DatetimeIndex(df_o['Incident_Date']).month
df_o.head()
# Out:
#    Incident_ID    Incident_Date         State        CityorCounty  Num_Killed  \
# 0       635289  August 21, 2016     Louisiana         New Orleans           1
# 1       633604  August 18, 2016    California         Porterville           0
# 2       631856  August 16, 2016      Illinois  Chicago (Roseland)           0
# 3       629549  August 14, 2016       Georgia            Marietta           0
# 4       629915  August 14, 2016  South Dakota            Aberdeen           0
#
#    Num_Injured  year  month
# 0            1  2016      8
# 1            2  2016      8
# 2            1  2016      8
# 3            2  2016      8
# 4            2  2016      8

# %%
#create tables with year and month sparced
tableName = 'accidental_deaths_timed'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = df_ad.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table accidental_deaths_timed created successfully.

# %%
#create tables with year and month sparced
tableName = 'mass_shooting_timed'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = df_ms.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table mass_shooting_timed created successfully.

# %%
#create tables with year and month sparced
tableName = 'officer_involved_shooting_timed'
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = df_o.to_sql(tableName, dbConnection, if_exists='append');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);   

finally:

    dbConnection.close()
# Out:
# Table officer_involved_shooting_timed created successfully.

# %%
#check table names finally
sqlEngine       = create_engine('mysql+pymysql://root:SQL_1294#@localhost:3306/msds_530_db', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

print(sqlEngine.table_names())

dbConnection.close()
# Out:
# ['accidental_deaths', 'accidental_deaths_by_state', 'accidental_deaths_timed', 'accidental_deaths_updated', 'mass_shooting_timed', 'mass_shootings', 'mass_shootings_by_state', 'officer_involved_deaths_by_state', 'officer_involved_shooting_timed', 'officer_involved_shootings', 'uservitals']
# C:\Users\niran\AppData\Local\Temp\ipykernel_33304\2423484867.py:5: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(sqlEngine.table_names())
